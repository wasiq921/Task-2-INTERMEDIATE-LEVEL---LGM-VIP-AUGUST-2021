# %% [markdown]
# <a href="https://colab.research.google.com/github/wasiq921/Task-2-INTERMEDIATE-LEVEL---LGM-VIP-AUGUST-2021/blob/main/Task_2_(Intermediate_Level)_LGM_VIP_AUGUST_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 2 (Intermediate Level) Prediction using Decision Tree  Algorithm
#
# ## Author: Muhammad Wasiq
#
# ### LGM VIP August 2021

# %%
#import all required libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
from sklearn import tree

# %%
#import dataset
df = pd.read_csv('/content/sample_data/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# Successfully Imported and Load our Dataset
# and now start Data Analysis

# %%
#checking for null values
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# No null value in our dataset

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# There is 150 rows and 6 Columns in dataset

# %%
#splitting Data
fc = [x for x in df.columns if x!="Species"]
x= df[fc]
y= df["Species"]
X_train, X_test, Y_train, Y_test = train_test_split(x,y, random_state = 100, test_size = 0.30)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (105, 5)
# (45, 5)
# (105,)
# (45,)

# %% [markdown]
# Building Decision Tree Model

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
Y_pred = model.predict(X_test)

# %%
df2 = pd.DataFrame({"Actual":Y_test,"Predicted":Y_pred})
df2.head()
# Out:
#              Actual       Predicted
# 128  Iris-virginica  Iris-virginica
# 11      Iris-setosa     Iris-setosa
# 118  Iris-virginica  Iris-virginica
# 15      Iris-setosa     Iris-setosa
# 123  Iris-virginica  Iris-virginica

# %% [markdown]
# Now test Accuracy of Model Prediction

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 1.0

# %%
# Plotting
f_n = ["Sepal length", "Sepal width", "Petal length", "Petal width"]
c_n = ["Setosa", "Versicolor", "Virginica"]
plot_tree(model,feature_names = f_n, class_names = c_n , filled = True)
# Out:
# [Text(133.92000000000002, 181.2, 'Petal width <= 2.45\ngini = 0.664\nsamples = 105\nvalue = [34, 39, 32]\nclass = Versicolor'),
#  Text(66.96000000000001, 108.72, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]\nclass = Setosa'),
#  Text(200.88000000000002, 108.72, 'Sepal length <= 100.0\ngini = 0.495\nsamples = 71\nvalue = [0, 39, 32]\nclass = Versicolor'),
#  Text(133.92000000000002, 36.23999999999998, 'gini = 0.0\nsamples = 39\nvalue = [0, 39, 0]\nclass = Versicolor'),
#  Text(267.84000000000003, 36.23999999999998, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 32]\nclass = Virginica')]

# %%
model1= DecisionTreeClassifier().fit(x,y)

plt.figure(figsize = (20,15))
tree = tree.plot_tree(model1, feature_names = f_n, class_names = c_n, filled = True)
